# %% [markdown]
# # Learning how to Describe, Clean and Manupulate Data Using  My perfomance Score Cards

# %%
# loading in the required Libraries

import pandas as pd
import seaborn as sns
import numpy as np

# %%
# Reading  in My Score Cards Date Set
Score_Card = pd.read_csv(r'C:\Users\DMONGARE\Desktop\J projects\Pefomance Data.csv')

# %%
# Taking a look  at  my Data Set

Score_Card.head(27)
# Out:
#                                             KPIs     Apr-19     May-19  \
# 0                                   Call Quality     98.14%     98.50%
# 1                                    SMS Quality  Not Apply  Not Apply
# 2                                Service Request  Not Apply  Not Apply
# 3                                  eMail Quality  Not Apply  Not Apply
# 4                          Quality of Escalation       100%       100%
# 5                Customer Feedback(Satisfaction)     70.09%     74.88%
# 6                  Customer Feedback(Resolution)     80.80%     71.30%
# 7                         Customer Feedback(NPS)     33.04%     25.93%
# 8                             Chat(Availability)        NaN        NaN
# 9                               Chat(Efficiency)        NaN        NaN
# 10                              Reversals Closed        NaN        NaN
# 11                                       Reports          |          |
# ...

# %%
Score_Card.shape
# Out:
# (26, 26)

# %%
# checking columns

Score_Card.columns
# Out:
# Index(['KPIs', 'Apr-19', 'May-19', 'Jun-19', 'Jul-19', 'Aug-19', 'Sep-19',
#        'Oct-19', 'Nov-19', 'Dec-19', 'Jan-20', 'Feb-20', 'Mar-20', 'Apr-20',
#        'Apr-20.1', 'May-20', 'Jun-20', 'Jul-20', 'Aug-20', 'Sep-20', 'Oct-20',
#        'Nov-20', 'Dec-20', 'Jan-21', 'Feb-21', 'Mar-21'],
#       dtype='object')

# %%
# Deleting Rows and Columns

# a) Rows :  I am going to drop row  'Unnamed: 1'

Score_Card.drop('KPIs',axis=1,inplace=True)

# %%
Score_Card.head()
# Out:
#       May-19     Jun-19     Jul-19     Aug-19     Sep-19     Oct-19  \
# 0     98.50%     99.50%     97.80%     95.22%        99%     91.30%
# 1  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply
# 2  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply
# 3  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply
# 4       100%       100%       100%     96.43%     97.06%        88%
#
#       Nov-19     Dec-19     Jan-20     Feb-20  ...     Jun-20     Jul-20  \
# 0     99.50%     97.78%       100%     98.38%  ...     96.98%     97.74%
# 1  Not Apply  Not Apply  Not Apply  Not Apply  ...  Not Apply  Not Apply
# 2  Not Apply  Not Apply  Not Apply  Not Apply  ...  Not Apply  Not Apply
# 3  Not Apply  Not Apply  Not Apply  Not Apply  ...  Not Apply  Not Apply
# 4        85%       100%       100%       100%  ...     96.15%        92%
#
#       Aug-20     Sep-20     Oct-20     Nov-20     Dec-20     Jan-21  \
# ...

# %%
# Deleting more than one  columns
# Create a new data frame

Score_Card.columns
# Out:
# Index(['May-19', 'Jun-19', 'Jul-19', 'Aug-19', 'Sep-19', 'Oct-19', 'Nov-19',
#        'Dec-19', 'Jan-20', 'Feb-20', 'Mar-20', 'Apr-20', 'Apr-20.1', 'May-20',
#        'Jun-20', 'Jul-20', 'Aug-20', 'Sep-20', 'Oct-20', 'Nov-20', 'Dec-20',
#        'Jan-21', 'Feb-21', 'Mar-21'],
#       dtype='object')

# %%
Score_Card.columns[[1,11,20]]
# Out:
# Index(['Jun-19', 'Apr-20', 'Dec-20'], dtype='object')

# %%
Score_Card1 = Score_Card.drop(Score_Card.columns[[2,11,20]],axis=1)
Score_Card1.head()
# Out:
#       May-19     Jun-19     Aug-19     Sep-19     Oct-19     Nov-19  \
# 0     98.50%     99.50%     95.22%        99%     91.30%     99.50%
# 1  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply
# 2  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply
# 3  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply
# 4       100%       100%     96.43%     97.06%        88%        85%
#
#       Dec-19     Jan-20     Feb-20     Mar-20  ...     May-20     Jun-20  \
# 0     97.78%       100%     98.38%        99%  ...     92.32%     96.98%
# 1  Not Apply  Not Apply  Not Apply  Not Apply  ...  Not Apply  Not Apply
# 2  Not Apply  Not Apply  Not Apply  Not Apply  ...  Not Apply  Not Apply
# 3  Not Apply  Not Apply  Not Apply  Not Apply  ...  Not Apply  Not Apply
# 4       100%       100%       100%     95.83%  ...        96%     96.15%
#
#       Jul-20     Aug-20     Sep-20     Oct-20     Nov-20     Jan-21  \
# ...

# %%
# b) Deteing Rows

Score_Card.drop(0)
# Out:
#        May-19     Jun-19     Jul-19     Aug-19     Sep-19     Oct-19  \
# 1   Not Apply  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply
# 2   Not Apply  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply
# 3   Not Apply  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply
# 4        100%       100%       100%     96.43%     97.06%        88%
# 5      74.88%     71.28%     71.35%     72.97%     70.94%     74.32%
# 6      71.30%     82.27%     66.67%     79.38%     82.91%     84.35%
# 7      25.93%     22.70%     16.67%     38.13%     32.48%     46.26%
# 8         NaN        NaN        NaN        NaN        NaN        NaN
# 9         NaN        NaN        NaN        NaN        NaN        NaN
# 10        NaN        NaN        NaN        NaN        NaN        NaN
# 11          |          |          |          |          |          |
# 12     97.61%     98.22%     99.70%     99.35%     95.49%     98.18%
# 13        NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
Score_Card.drop(6)
# Out:
#        May-19     Jun-19     Jul-19     Aug-19     Sep-19     Oct-19  \
# 0      98.50%     99.50%     97.80%     95.22%        99%     91.30%
# 1   Not Apply  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply
# 2   Not Apply  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply
# 3   Not Apply  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply
# 4        100%       100%       100%     96.43%     97.06%        88%
# 5      74.88%     71.28%     71.35%     72.97%     70.94%     74.32%
# 7      25.93%     22.70%     16.67%     38.13%     32.48%     46.26%
# 8         NaN        NaN        NaN        NaN        NaN        NaN
# 9         NaN        NaN        NaN        NaN        NaN        NaN
# 10        NaN        NaN        NaN        NaN        NaN        NaN
# 11          |          |          |          |          |          |
# 12     97.61%     98.22%     99.70%     99.35%     95.49%     98.18%
# 13        NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %% [markdown]
# # Deleting Multiple Rows using diffrent functions
#
# # i) Loc Method

# %%
#  used for selecting things by label

# The below loc[] code shows how to select the   first row of the data set/Frame:

Score_Card.loc[0, :]
# Out:
# May-19      98.50%
# Jun-19      99.50%
# Jul-19      97.80%
# Aug-19      95.22%
# Sep-19         99%
# Oct-19      91.30%
# Nov-19      99.50%
# Dec-19      97.78%
# Jan-20        100%
# Feb-20      98.38%
# Mar-20         99%
# Apr-20       97.66
# Apr-20.1    97.45%
# May-20      92.32%
# Jun-20      96.98%
# Jul-20      97.74%
# Aug-20         99%
# Sep-20      97.32%
# Oct-20      95.14%
# Nov-20        100%
# Dec-20      98.50%
# Jan-21      91.91%
# Feb-21      98.11%
# Mar-21         NaN
# Name: 0, dtype: object

# %%
# Selecting different  multiple Rows

Score_Card.loc[[1,3,5,6,7,8,17,20,21,22], :]
# Out:
#        May-19     Jun-19     Jul-19     Aug-19     Sep-19     Oct-19  \
# 1   Not Apply  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply
# 3   Not Apply  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply
# 5      74.88%     71.28%     71.35%     72.97%     70.94%     74.32%
# 6      71.30%     82.27%     66.67%     79.38%     82.91%     84.35%
# 7      25.93%     22.70%     16.67%     38.13%     32.48%     46.26%
# 8         NaN        NaN        NaN        NaN        NaN        NaN
# 17          |          |          |          |          |          |
# 20       18 |       16 |       16 |       16 |       15 |       15 |
# 21        6 |        7 |        6 |        6 |        6 |        6 |
# 22        NaN        NaN        NaN        NaN        NaN        NaN
#
#        Nov-19     Dec-19     Jan-20     Feb-20  ...     Jun-20     Jul-20  \
# 1   Not Apply  Not Apply  Not Apply  Not Apply  ...  Not Apply  Not Apply
# ...

# %%
# Another method of selecting  multiple rows 
# Nothe:  its also includes row 12

Score_Card.loc[0:12, :]
# Out:
#        May-19     Jun-19     Jul-19     Aug-19     Sep-19     Oct-19  \
# 0      98.50%     99.50%     97.80%     95.22%        99%     91.30%
# 1   Not Apply  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply
# 2   Not Apply  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply
# 3   Not Apply  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply
# 4        100%       100%       100%     96.43%     97.06%        88%
# 5      74.88%     71.28%     71.35%     72.97%     70.94%     74.32%
# 6      71.30%     82.27%     66.67%     79.38%     82.91%     84.35%
# 7      25.93%     22.70%     16.67%     38.13%     32.48%     46.26%
# 8         NaN        NaN        NaN        NaN        NaN        NaN
# 9         NaN        NaN        NaN        NaN        NaN        NaN
# 10        NaN        NaN        NaN        NaN        NaN        NaN
# 11          |          |          |          |          |          |
# 12     97.61%     98.22%     99.70%     99.35%     95.49%     98.18%
#
# ...

# %%
# Selecting columns using the Loc[] method

Score_Card.loc[:, 'Jul-19']
# Out:
# 0        97.80%
# 1     Not Apply
# 2     Not Apply
# 3     Not Apply
# 4          100%
# 5        71.35%
# 6        66.67%
# 7        16.67%
# 8           NaN
# 9           NaN
# 10          NaN
# 11            |
# 12       99.70%
# 13          NaN
# 14          NaN
# 15          NaN
# 16      27| 198
# 17            |
# 18            |
# 19         1169
# 20         16 |
# 21          6 |
# 22          NaN
# 23       88.09%
# 24          NaN
# 25          NaN
# Name: Jul-19, dtype: object

# %%
# Selecting multiple columns using the Loc[] method

Score_Card.loc[:, 'Jul-19':'Oct-19']
# Out:
#        Jul-19     Aug-19     Sep-19     Oct-19
# 0      97.80%     95.22%        99%     91.30%
# 1   Not Apply  Not Apply  Not Apply  Not Apply
# 2   Not Apply  Not Apply  Not Apply  Not Apply
# 3   Not Apply  Not Apply  Not Apply  Not Apply
# 4        100%     96.43%     97.06%        88%
# 5      71.35%     72.97%     70.94%     74.32%
# 6      66.67%     79.38%     82.91%     84.35%
# 7      16.67%     38.13%     32.48%     46.26%
# 8         NaN        NaN        NaN        NaN
# 9         NaN        NaN        NaN        NaN
# 10        NaN        NaN        NaN        NaN
# 11          |          |          |          |
# 12     99.70%     99.35%     95.49%     98.18%
# 13        NaN        NaN        NaN        NaN
# 14        NaN        NaN        NaN        NaN
# 15        NaN        NaN        NaN        NaN
# 16    27| 198    19| 208    20| 217   19 | 208
# 17          |          |          |          |
# 18          |          |          |          |
# ...

# %%
# You can combine Both rows and column with one function code

Score_Card.loc[0:6, 'Jul-19':'Oct-19']
# Out:
#       Jul-19     Aug-19     Sep-19     Oct-19
# 0     97.80%     95.22%        99%     91.30%
# 1  Not Apply  Not Apply  Not Apply  Not Apply
# 2  Not Apply  Not Apply  Not Apply  Not Apply
# 3  Not Apply  Not Apply  Not Apply  Not Apply
# 4       100%     96.43%     97.06%        88%
# 5     71.35%     72.97%     70.94%     74.32%
# 6     66.67%     79.38%     82.91%     84.35%

# %%
# selecting multiple rows and columns without the lock menthod

Score_Card.head(6).drop('May-19',axis=1)
# Out:
#       Jun-19     Jul-19     Aug-19     Sep-19     Oct-19     Nov-19  \
# 0     99.50%     97.80%     95.22%        99%     91.30%     99.50%
# 1  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply
# 2  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply
# 3  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply
# 4       100%       100%     96.43%     97.06%        88%        85%
# 5     71.28%     71.35%     72.97%     70.94%     74.32%     68.82%
#
#       Dec-19     Jan-20     Feb-20     Mar-20  ...     Jun-20     Jul-20  \
# 0     97.78%       100%     98.38%        99%  ...     96.98%     97.74%
# 1  Not Apply  Not Apply  Not Apply  Not Apply  ...  Not Apply  Not Apply
# 2  Not Apply  Not Apply  Not Apply  Not Apply  ...  Not Apply  Not Apply
# 3  Not Apply  Not Apply  Not Apply  Not Apply  ...  Not Apply  Not Apply
# 4       100%       100%       100%     95.83%  ...     96.15%        92%
# ...

# %%
# Iloc [] Mthod

# is for filtering rows and selecting columns bY Interger positon. Thats what the i stands for I.E Integer

# In below I am selecting 2 specific rows using the iloc menthod


Score_Card.iloc[:, [0,3]]
# Out:
#        May-19     Aug-19
# 0      98.50%     95.22%
# 1   Not Apply  Not Apply
# 2   Not Apply  Not Apply
# 3   Not Apply  Not Apply
# 4        100%     96.43%
# 5      74.88%     72.97%
# 6      71.30%     79.38%
# 7      25.93%     38.13%
# 8         NaN        NaN
# 9         NaN        NaN
# 10        NaN        NaN
# 11          |          |
# 12     97.61%     99.35%
# 13        NaN        NaN
# 14        NaN        NaN
# 15        NaN        NaN
# 16    20| 179    19| 208
# 17          |          |
# 18          |          |
# 19       2965       2908
# 20       18 |       16 |
# 21        6 |        6 |
# 22        NaN        NaN
# 23     86.70%     86.64%
# 24        NaN        NaN
# 25        NaN        NaN

# %% [markdown]
# # Iloc [] Mthod

# %%
# If I want to select a Range of Columns

Score_Card.columns
# Out:
# Index(['May-19', 'Jun-19', 'Jul-19', 'Aug-19', 'Sep-19', 'Oct-19', 'Nov-19',
#        'Dec-19', 'Jan-20', 'Feb-20', 'Mar-20', 'Apr-20', 'Apr-20.1', 'May-20',
#        'Jun-20', 'Jul-20', 'Aug-20', 'Sep-20', 'Oct-20', 'Nov-20', 'Dec-20',
#        'Jan-21', 'Feb-21', 'Mar-21'],
#       dtype='object')

# %%
Score_Card.iloc[:, 0:4]
# Out:
#        May-19     Jun-19     Jul-19     Aug-19
# 0      98.50%     99.50%     97.80%     95.22%
# 1   Not Apply  Not Apply  Not Apply  Not Apply
# 2   Not Apply  Not Apply  Not Apply  Not Apply
# 3   Not Apply  Not Apply  Not Apply  Not Apply
# 4        100%       100%       100%     96.43%
# 5      74.88%     71.28%     71.35%     72.97%
# 6      71.30%     82.27%     66.67%     79.38%
# 7      25.93%     22.70%     16.67%     38.13%
# 8         NaN        NaN        NaN        NaN
# 9         NaN        NaN        NaN        NaN
# 10        NaN        NaN        NaN        NaN
# 11          |          |          |          |
# 12     97.61%     98.22%     99.70%     99.35%
# 13        NaN        NaN        NaN        NaN
# 14        NaN        NaN        NaN        NaN
# 15        NaN        NaN        NaN        NaN
# 16    20| 179    25| 186    27| 198    19| 208
# 17          |          |          |          |
# 18          |          |          |          |
# ...

# %%
# Selecting multiple rows using the Ilock menthod

# Note that it does not select Row 5

 
Score_Card.iloc[0:5, :]
# Out:
#       May-19     Jun-19     Jul-19     Aug-19     Sep-19     Oct-19  \
# 0     98.50%     99.50%     97.80%     95.22%        99%     91.30%
# 1  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply
# 2  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply
# 3  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply
# 4       100%       100%       100%     96.43%     97.06%        88%
#
#       Nov-19     Dec-19     Jan-20     Feb-20  ...     Jun-20     Jul-20  \
# 0     99.50%     97.78%       100%     98.38%  ...     96.98%     97.74%
# 1  Not Apply  Not Apply  Not Apply  Not Apply  ...  Not Apply  Not Apply
# 2  Not Apply  Not Apply  Not Apply  Not Apply  ...  Not Apply  Not Apply
# 3  Not Apply  Not Apply  Not Apply  Not Apply  ...  Not Apply  Not Apply
# 4        85%       100%       100%       100%  ...     96.15%        92%
#
#       Aug-20     Sep-20     Oct-20     Nov-20     Dec-20     Jan-21  \
# ...

# %% [markdown]
# # This show the diffence in selcting rows and columns while using both the lock[]  and ilock[] method
#
# # lock[] method is used for labels, Ilock[] for integer position
#
# # Lock[] when you do ranges because it inludes both sides, While Ilock  is inclussive on the start and exclussive of the stop

# %% [markdown]
# # Combing Columns in a DataFrame or Data set

# %%
# Note that we no longer have row 0 in our new data set New_Score . 

New_Score = Score_Card.drop(3)

# %%
New_Score
# Out:
#        May-19     Jun-19     Jul-19     Aug-19     Sep-19     Oct-19  \
# 0      98.50%     99.50%     97.80%     95.22%        99%     91.30%
# 1   Not Apply  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply
# 2   Not Apply  Not Apply  Not Apply  Not Apply  Not Apply  Not Apply
# 4        100%       100%       100%     96.43%     97.06%        88%
# 5      74.88%     71.28%     71.35%     72.97%     70.94%     74.32%
# 6      71.30%     82.27%     66.67%     79.38%     82.91%     84.35%
# 7      25.93%     22.70%     16.67%     38.13%     32.48%     46.26%
# 8         NaN        NaN        NaN        NaN        NaN        NaN
# 9         NaN        NaN        NaN        NaN        NaN        NaN
# 10        NaN        NaN        NaN        NaN        NaN        NaN
# 11          |          |          |          |          |          |
# 12     97.61%     98.22%     99.70%     99.35%     95.49%     98.18%
# 13        NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
# I am trying  to merge two columns  of a single data set to see if the code works for me before we begin the merge operation

# Below are some of the different ways to merge columns without the merge function()

New_Score["KPI"] = New_Score["Jun-19"].astype(str) + New_Score["Sep-19"]

# %%
New_Score["KPI"]
# Out:
# 0              99.50%99%
# 1     Not ApplyNot Apply
# 2     Not ApplyNot Apply
# 4             100%97.06%
# 5           71.28%70.94%
# 6           82.27%82.91%
# 7           22.70%32.48%
# 8                    NaN
# 9                    NaN
# 10                   NaN
# 11                    ||
# 12          98.22%95.49%
# 13                   NaN
# 14                   NaN
# 15                   NaN
# 16        25| 18620| 217
# 17                    ||
# 18                    ||
# 19              23802362
# 20              16 |15 |
# 21                7 |6 |
# 22                   NaN
# 23          87.81%86.88%
# 24                  nan1
# 25                   NaN
# Name: KPI, dtype: object

# %%
# Other Format and This one will work for me

New_Score['All_Kpi'] =  New_Score['Jun-19'] + '-' + New_Score['Sep-19'].astype(str)

# %%
New_Score['All_Kpi']
# Out:
# 0              99.50%-99%
# 1     Not Apply-Not Apply
# 2     Not Apply-Not Apply
# 4             100%-97.06%
# 5           71.28%-70.94%
# 6           82.27%-82.91%
# 7           22.70%-32.48%
# 8                     NaN
# 9                     NaN
# 10                    NaN
# 11                    |-|
# 12          98.22%-95.49%
# 13                    NaN
# 14                    NaN
# 15                    NaN
# 16        25| 186-20| 217
# 17                    |-|
# 18                    |-|
# 19              2380-2362
# 20              16 |-15 |
# 21                7 |-6 |
# 22                    NaN
# 23          87.81%-86.88%
# 24                    NaN
# 25                    NaN
# Name: All_Kpi, dtype: object

# %%
New_Score['All_Kpi'] =  New_Score['Jun-19'] + '-' + New_Score['Sep-19']

# %%
New_Score['All_Kpi']
# Out:
# 0              99.50%-99%
# 1     Not Apply-Not Apply
# 2     Not Apply-Not Apply
# 4             100%-97.06%
# 5           71.28%-70.94%
# 6           82.27%-82.91%
# 7           22.70%-32.48%
# 8                     NaN
# 9                     NaN
# 10                    NaN
# 11                    |-|
# 12          98.22%-95.49%
# 13                    NaN
# 14                    NaN
# 15                    NaN
# 16        25| 186-20| 217
# 17                    |-|
# 18                    |-|
# 19              2380-2362
# 20              16 |-15 |
# 21                7 |-6 |
# 22                    NaN
# 23          87.81%-86.88%
# 24                    NaN
# 25                    NaN
# Name: All_Kpi, dtype: object
